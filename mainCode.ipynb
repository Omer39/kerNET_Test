# %% [markdown]
# <a href="https://colab.research.google.com/github/Omer39/kerNET_Test/blob/main/mainCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# %cd /content/gdrive/My\ Drive/ColabNotebooks/project_folder
import os
os.listdir()
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/My Drive/ColabNotebooks/project_folder
# ['kerNET', '.ipynb_checkpoints', 'mainCode.ipynb']

# %%
#! git clone https://github.com/michaelshiyu/kerNET.git
# Out:
# fatal: destination path 'kerNET' already exists and is not an empty directory.

# %%
#! git pull https://github.com/michaelshiyu/kerNET.git
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
ls
# Out:
# kernet/  LICENSE.md        README.md         scripts/  test/
# legacy/  modular_train.py  requirements.txt  setup.py  tutorials/

# %%
# %cd /content/gdrive/My\ Drive/ColabNotebooks/project_folder/kerNET
# Out:
# /content/gdrive/My Drive/ColabNotebooks/project_folder/kerNET

# %%
! python modular_train.py --dataset cifar10 --model kresnet18 --n_parts 2 --loss xe --lr1 .1 --lr2 .1 --activation reapen --optimizer sgd --n_epochs1 200 --n_epochs2 50 --hidden_objective srs_upper_tri_alignment --in_channels 3 --batch_size 128  --save_dir my_checkpoint --n_val 5000
# Out:
# Streaming output truncated to the last 5000 lines.
# [part: 2, epoch:    44/50] avg loss (crossentropyloss): 0.385, avg acc (%): 88.976, avg runtime (s): 0.030
# [>>>>>>>>--] 282/352, 26.2 batches/s, elapsed: 11s, ETA:     3s
# [part: 2, epoch:    44/50] avg loss (crossentropyloss): 0.386, avg acc (%): 88.977, avg runtime (s): 0.030
# [>>>>>>>>--] 283/352, 26.2 batches/s, elapsed: 11s, ETA:     3s
# [part: 2, epoch:    44/50] avg loss (crossentropyloss): 0.385, avg acc (%): 88.982, avg runtime (s): 0.030
# [>>>>>>>>--] 284/352, 26.1 batches/s, elapsed: 11s, ETA:     3s
# [part: 2, epoch:    44/50] avg loss (crossentropyloss): 0.386, avg acc (%): 88.972, avg runtime (s): 0.030
# [>>>>>>>>--] 285/352, 26.1 batches/s, elapsed: 11s, ETA:     3s
# [part: 2, epoch:    44/50] avg loss (crossentropyloss): 0.385, avg acc (%): 88.988, avg runtime (s): 0.030
# [>>>>>>>>--] 286/352, 26.1 batches/s, elapsed: 11s, ETA:     3s
# ...

# %%
! python test.py --load_opt --opt_file my_checkpoint/opt.pkl --checkpoint_dir my_checkpoint
# Out:
# ----------------- Options ---------------
# ----------------- Options ---------------
#                activation: reapen
#               adversarial: False
#             adversary_eps: 0.3
#            adversary_norm: inf
#                  balanced: False
#                batch_size: 128
#            checkpoint_dir: my_checkpoint                 	[default: None]
#                data_shape: (3, 32, 32)
#                   dataset: cifar10
#               expert_size: 300
#               in_channels: 3
#                  is_train: False                         	[default: None]
#                load_model: False
#                  load_opt: True                          	[default: False]
#                  loglevel: INFO
#          max_testset_size: 1000000000000
#          memory_efficient: False
#                     model: kresnet18
#                 multi_gpu: False
#                 n_centers: 1000
#                 n_classes: 10
#                   n_parts: 2
# ...

# %%
ls
# Out:
#  data/                                                 __pycache__/
#  kernet/                                               README.md
#  legacy/                                               requirements.txt
#  LICENSE.md                                            scripts/
#  modular_train.py                                      setup.py
#  my_checkpoint/                                        test/
# 'my_checkpoint_archived_2021-06-27 17:22:44.899705'/   test.py
# 'my_checkpoint_archived_2021-06-27 17:23:17.598366'/   tutorials/
# 'my_checkpoint_archived_2021-06-27 18:11:24.062699'/

# %%
test.log
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a86524cf6d7b> in <module>()
# ----> 1 test.log
#
# NameError: name 'test' is not defined
